# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # 데이터셋 생성
# 간단하게 다음 generate_time_series() 함수로 생성한 시계열을 사용하겠습니다.

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10))  #   웨이브 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # + 웨이브 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5)   # + 잡음
    return series[..., np.newaxis].astype(np.float32)

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
import matplotlib.pyplot as plt

def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$", legend=True):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bo", label="Target")
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "rx", markersize=10, label="Prediction")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])
    if legend and (y or y_pred):
        plt.legend(fontsize=14, loc="upper left")

fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12, 4))
for col in range(3):
    plt.sca(axes[col])
    plot_series(X_valid[col, :, 0], y_valid[col, 0],
                y_label=("$x(t)$" if col==0 else None),
                legend=(col == 0))
plt.show()

# %% [markdown]
# # 기준 성능
# RNN 시작 전 기준 성능을 몇 개 준비하는 게 좋습니다.<br>
# 그렇지 않으면 실제 기본 모델보다 성능이 나쁠 때도 잘 작동한다고 착각할 수 있습니다.
#
# 가장 간단한 것 중 하나는 각 시계열의 마지막 값을 그대로 예측하는 것입니다.<br>
# 이를 순진한 예측이라고 부르고, 가끔 이 성능을 뛰어넘는 게 매우 어렵습니다.

# %%
y_pred = X_valid[:, -1]
np.mean(keras.losses.mean_squared_error(y_valid, y_pred))
# Out:
# 0.020211367

# %% [markdown]
# 이 경우에는 0.02의 오차가 생깁니다.

# %% [markdown]
# 또 다른 간단한 방법은 완전 연결 네트워크를 사용하는 것입니다.<br>
# 이 네트워크는 입력마다 1차원 특성 배열을 기대하기 때문에 Flatten 층을 추ㅏ해야 합니다.<br>
# 시계열 값의 선형 조합으로 예측하기 위해 간단한 선형 회귀 모델을 사용하겠습니다.

# %%
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(1)
])

model.compile(loss='mse', optimizer='adam')
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.1001 - val_loss: 0.0545
# Epoch 2/20
# 219/219 [==============================] - 0s 959us/step - loss: 0.0379 - val_loss: 0.0266
# Epoch 3/20
# 219/219 [==============================] - 0s 868us/step - loss: 0.0202 - val_loss: 0.0157
# Epoch 4/20
# 219/219 [==============================] - 0s 904us/step - loss: 0.0131 - val_loss: 0.0116
# Epoch 5/20
# 219/219 [==============================] - 0s 852us/step - loss: 0.0103 - val_loss: 0.0098
# Epoch 6/20
# 219/219 [==============================] - 0s 812us/step - loss: 0.0089 - val_loss: 0.0087
# Epoch 7/20
# 219/219 [==============================] - 0s 862us/step - loss: 0.0080 - val_loss: 0.0079
# Epoch 8/20
# 219/219 [==============================] - 0s 795us/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 9/20
# 219/219 [==============================] - 0s 846us/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 10/20
# 219/219 [==============================] - 0s 786us/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 11/20
# 219/219 [==============================] - 0s 752us/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 12/20
# 219/219 [==============================] - 0s 767us/step - loss: 0.0054 - val_loss: 0.0055
# Epoch 13/20
# 219/219 [==============================] - 0s 785us/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 14/20
# 219/219 [==============================] - 0s 848us/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 15/20
# 219/219 [==============================] - 0s 748us/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 16/20
# 219/219 [==============================] - 0s 780us/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 17/20
# 219/219 [==============================] - 0s 761us/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 18/20
# 219/219 [==============================] - 0s 904us/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 19/20
# 219/219 [==============================] - 0s 894us/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 20/20
# 219/219 [==============================] - 0s 780us/step - loss: 0.0042 - val_loss: 0.0042

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 613us/step - loss: 0.0042
# 0.004168087150901556

# %% [markdown]
# 0.004의 MSE 값을 얻었습니다. 순진한 예측보다 훨씬 낫습니다.

# %% [markdown]
# # 간단한 RNN 구현하기
# 간단한 RNN을 사용해 기준 성능을 앞지를 수 있는지 확인하겠습니다.

# %%
model = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None, 1])
])

# %% [markdown]
# 위 코드가 가장 간단하게 만들 수 있는 RNN입니다.
#
# 하나의 뉴런으로 이루어진 하나의 층을 가집니다.<br>
# 순환 신경망은 어떤 길이의 타임 스텝도 처리할 수 있기 때문에 입력 시퀀스의 길이를 지정할 필요가 없습니다.<br>
# 기본적으로 SimpleRNN 층은 하이퍼볼릭 탄젠트 활성화 함수를 사용합니다.

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.005)
model.compile(loss="mse", optimizer=optimizer)
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 2s 5ms/step - loss: 0.0313 - val_loss: 0.0127
# Epoch 2/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0119 - val_loss: 0.0112
# Epoch 3/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0115 - val_loss: 0.0110
# Epoch 4/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 5/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 6/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 7/20
# 219/219 [==============================] - 1s 4ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 8/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 9/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 10/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0110
# Epoch 11/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 12/20
# 219/219 [==============================] - 1s 4ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 13/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 14/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 15/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 16/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 17/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 18/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 19/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 20/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0114 - val_loss: 0.0109

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0109
# 0.01090716291218996

# %% [markdown]
# 0.0109의 MSE를 얻었습니다.<br>
# 순진한 예측보다는 낫지만 간단한 선형 모델을 앞지르지는 못했습니다.

# %% [markdown]
# # 심층 RNN
# tf.keras로 심층 RNN을 구현하는 것은 쉽습니다.<br>
# 그냥 아래처럼 순환 층을 쌓으면 됩니다.

# %%
model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.SimpleRNN(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 4s 14ms/step - loss: 0.0175 - val_loss: 0.0051
# Epoch 2/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 3/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 4/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 5/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 6/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 7/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 8/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 9/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 10/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 11/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 12/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 13/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 14/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 15/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 16/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 17/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 18/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 19/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 20/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0028 - val_loss: 0.0026

# %% [markdown]
# 이 때 모든 순환 층에서 return_sequences=True로 설정해야 합니다.<br>
# (마지막 출력만 관심 대상이면 마지막 층에서는 설정하지 않습니다.)
#
# 그렇지 않으면 모든 타임 스텝에 대한 출력을 담은 3D 배열이 아니라<br>
# 마지막 타임 스텝의 출력만 담은 2D 배열이 출력되고<br>
# 순환 층이 3D 형태로 시퀀스를 받지 못하기 때문에 작동하지 못합니다.

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0026
# 0.0026385621167719364

# %% [markdown]
# 이렇게 만든 모델은 0.0026의 MSE를 기록합니다.<br>
# 드디어 기준 성능을 뛰어넘었습니다.

# %% [markdown]
# 그런데 이 때 마지막 층은 이상적이지 않습니다.<br>
# 하나의 유닛을 가진다는 것은 은닉 상태가 하나의 숫자라는 뜻입니다.<br>
# 아마 이 RNN은 한 타임 스텝에서 다음 스텝으로 필요한 모든 정보를 나르기 위해<br>
# 다른 순환 층의 은닉 상태를 주로 사용할 것입니다.<br>
# 이 때 마지막 층의 은닉 상태는 크게 필요하지 않습니다.
#
# 이런 이유로 출력층을 Dense 층으로 바꾸는 경우가 많습니다.<br>
# 더 빠르면서 정확도는 거의 비슷합니다.<br>
# 이렇게 바꾸려면 두 번째 순환 층에서 return_sequences=True를 제거합니다.

# %%
model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 3s 10ms/step - loss: 0.0869 - val_loss: 0.0084
# Epoch 2/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0059 - val_loss: 0.0045
# Epoch 3/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 4/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 5/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 6/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 7/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 8/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 9/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 10/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 11/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 12/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 13/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 14/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 15/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 16/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 17/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 18/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 19/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 20/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0027 - val_loss: 0.0027

# %% [markdown]
# 이 모델을 훈련하면 수렴도 빠르고 성능도 좋습니다.<br>
# 또한 출력층의 활성화 함수를 원하는 함수로 바꿀 수도 있습니다.

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0027
# 0.0026609303895384073

# %% [markdown]
# # 여러 타임 스텝 앞을 예측하기
# 첫 번째 방법은 이미 훈련된 모델을 사용하여 다음 값을 예측한 다음<br>
# 이 값을 입력으로 추가하는 것입니다(예측된 값이 실제 발견된 값인 것처럼 다룹니다.).
#
# 다음 코드와 같이 구현할 수 있습니다.

# %%
series = generate_time_series(1, n_steps + 10)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(10):
    y_pred_one = model.predict(X[:, step_ahead:])[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:]

# %%
def plot_multiple_forecasts(X, Y, Y_pred):
    n_steps = X.shape[1]
    ahead = Y.shape[1]
    plot_series(X[0, :, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), Y[0, :, 0], "bo-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), Y_pred[0, :, 0], "rx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)

plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# 위 그래프에서 볼 수 있듯이 가까운 미래에 대한 예측이 더 정확합니다.<br>
# 미래의 타임 스텝은 오차가 누적될 수 있기 때문입니다.
#
# 이 방식을 검증 세트에 적용하면 약 0.029의 MSE가 나오는데,<br>
# 이전 모델보다 크게 높지만 훨씬 어려운 작업을 했으므로 단순히 비교하기는 어렵습니다.<br>
# 따라서 같은 작업을 하는 단순한 예측이나 간단한 선형 모델과 비교하는 게 의미가 있습니다.
#
# 이렇게 비교를 한다면 이 모델이 단순한 예측이나 간단한 선형 모델보다 월등히 앞서는 것을 알 수 있습니다.

# %% [markdown]
# 두 번째 방법은 RNN을 훈련해 다음 값 10개를 한 번에 예측하는 것입니다.<br>
# 시퀀스-투-벡터 모델을 사용하고 1개가 아니라 값 10개를 출력합니다.
#
# 먼저 타깃을 다음 10개의 값이 담긴 벡터로 바꾸겠습니다.

# %%
n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train, Y_train = series[:7000, :n_steps], series[:7000, -10:, 0]
X_valid, Y_valid = series[7000:9000, :n_steps], series[7000:9000, -10:, 0]
X_test, Y_test = series[9000:, :n_steps], series[9000:, -10:, 0]

# %%
model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 3s 10ms/step - loss: 0.0581 - val_loss: 0.0262
# Epoch 2/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0195 - val_loss: 0.0169
# Epoch 3/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0148 - val_loss: 0.0155
# Epoch 4/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0133 - val_loss: 0.0137
# Epoch 5/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0122 - val_loss: 0.0116
# Epoch 6/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0114 - val_loss: 0.0104
# Epoch 7/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0108 - val_loss: 0.0104
# Epoch 8/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0105 - val_loss: 0.0099
# Epoch 9/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0104 - val_loss: 0.0103
# Epoch 10/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0097 - val_loss: 0.0092
# Epoch 11/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0101 - val_loss: 0.0101
# Epoch 12/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0096 - val_loss: 0.0088
# Epoch 13/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0094 - val_loss: 0.0088
# Epoch 14/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0095 - val_loss: 0.0092
# Epoch 15/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0090 - val_loss: 0.0085
# Epoch 16/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0091 - val_loss: 0.0082
# Epoch 17/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0092 - val_loss: 0.0098
# Epoch 18/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0089 - val_loss: 0.0083
# Epoch 19/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 20/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0088 - val_loss: 0.0089

# %% [markdown]
# 이제 예측을 한 번 해보겠습니다.

# %%
series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, -10:, :]
Y_pred = model.predict(X_new)[..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# 이 모델은 잘 작동하고, 다음 10개 타임 스텝에 대한 MSE는 약 0.008입니다.
# 선형 모델보다 훨씬 좋지만, 아직 개선할 여지가 있습니다.
#
# 마지막 타임 스텝에서만 다음 값 10개를 예측하도록 훈련하는 대신<br>
# 모든 타임 스텝에서 다음 값 10개를 예측하도록 모델을 훈련할 수 있습니다.
#
# 다르게 말하면 이 시퀀스-투-벡터 RNN을 시퀀스-투-시퀀스 RNN으로 바꾸는 것입니다.
#
# 타깃 시퀀스를 준비해봅시다.

# %%
n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train = series[:7000, :n_steps]
X_valid = series[7000:9000, :n_steps]
X_test = series[9000:, :n_steps]
Y = np.empty((10000, n_steps, 10))  # 각 타깃은 10D 벡터의 시퀀스
for step_ahead in range(1, 10 + 1):
    Y[..., step_ahead - 1] = series[..., step_ahead:step_ahead + n_steps, 0]
Y_train = Y[:7000]
Y_valid = Y[7000:9000]
Y_test = Y[9000:]

# %% [markdown]
# 이 모델을 시퀀스-투-시퀀스 모델로 바꾸려면 마지막 층을 포함한 모든 순환 층에 return_sequences=True를 지정해줘야 합니다. 그 다음 모든 타임 스텝에서 출력을 Dense층에 적용해야 합니다. 이를 위해서는 keras의 TimeDistributed층을 사용하면 됩니다. 이 층은 다른 층을 감싸서 입력 시퀀스의 모든 타임 스텝에 이를 적용합니다. 각 타임 스텝을 별개의 샘플처럼 다루게 입력의 크기를 바꿔 이를 효과적으로 수행합니다.

# %%
model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

# %% [markdown]
# 평가를 위해 마지막 타임 스텝의 출력에 대한 MSE만을 계산하는 사용자 정의 지표를 사용하겠습니다.

# %%
def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=0.01), metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 3s 10ms/step - loss: 0.0519 - last_time_step_mse: 0.0417 - val_loss: 0.0428 - val_last_time_step_mse: 0.0304
# Epoch 2/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0370 - last_time_step_mse: 0.0242 - val_loss: 0.0350 - val_last_time_step_mse: 0.0215
# Epoch 3/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0326 - last_time_step_mse: 0.0195 - val_loss: 0.0305 - val_last_time_step_mse: 0.0179
# Epoch 4/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0294 - last_time_step_mse: 0.0166 - val_loss: 0.0272 - val_last_time_step_mse: 0.0147
# Epoch 5/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0285 - last_time_step_mse: 0.0172 - val_loss: 0.0282 - val_last_time_step_mse: 0.0180
# Epoch 6/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0257 - last_time_step_mse: 0.0142 - val_loss: 0.0247 - val_last_time_step_mse: 0.0138
# Epoch 7/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0246 - last_time_step_mse: 0.0132 - val_loss: 0.0223 - val_last_time_step_mse: 0.0106
# Epoch 8/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0226 - last_time_step_mse: 0.0106 - val_loss: 0.0204 - val_last_time_step_mse: 0.0081
# Epoch 9/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0211 - last_time_step_mse: 0.0087 - val_loss: 0.0199 - val_last_time_step_mse: 0.0077
# Epoch 10/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0259 - last_time_step_mse: 0.0150 - val_loss: 0.0270 - val_last_time_step_mse: 0.0167
# Epoch 11/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0232 - last_time_step_mse: 0.0121 - val_loss: 0.0216 - val_last_time_step_mse: 0.0094
# Epoch 12/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0206 - last_time_step_mse: 0.0089 - val_loss: 0.0195 - val_last_time_step_mse: 0.0080
# Epoch 13/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0199 - last_time_step_mse: 0.0080 - val_loss: 0.0194 - val_last_time_step_mse: 0.0074
# Epoch 14/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0197 - last_time_step_mse: 0.0080 - val_loss: 0.0187 - val_last_time_step_mse: 0.0072
# Epoch 15/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0198 - last_time_step_mse: 0.0084 - val_loss: 0.0191 - val_last_time_step_mse: 0.0078
# Epoch 16/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0194 - last_time_step_mse: 0.0079 - val_loss: 0.0186 - val_last_time_step_mse: 0.0077
# Epoch 17/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0191 - last_time_step_mse: 0.0077 - val_loss: 0.0184 - val_last_time_step_mse: 0.0071
# Epoch 18/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0186 - last_time_step_mse: 0.0070 - val_loss: 0.0181 - val_last_time_step_mse: 0.0062
# Epoch 19/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0186 - last_time_step_mse: 0.0070 - val_loss: 0.0176 - val_last_time_step_mse: 0.0059
# Epoch 20/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0186 - last_time_step_mse: 0.0071 - val_loss: 0.0183 - val_last_time_step_mse: 0.0061

# %% [markdown]
# 검증 MSE로 0.006을 얻었습니다. 이전 결과보다 매우 좋은 결과입니다.

# %%
series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# 이런 방식을 처음 모델과 결합할 수 있습니다.<br>
# 이 RNN으로 다음 10개를 예측하고 이 값을 입력 시계열에 연결하고,<br>
# 모델을 다시 사용해 다음 값 10개를 예측합니다.
#
# 이 과정을 필요한 만큼 반복해서 어떤 길이의 시퀀스도 만들 수 있습니다.

# %% [markdown]
# # 불안정한 그레이디언트 문제와 싸우기
# tf.keras를 사용해 간단한 메모리 셀 안에 층 정규화를 구현해보겠습니다.<br>
# 이렇게 하려면 사용자 정의 메모리 셀을 정의해야 합니다.<br>
# 이 층은 call() 메소드가 다음 두 개의 매개변수를 받는 것을 제외하고는 일반적인 층입니다.
#
# 현재 타임 스텝의 inputs와 이전 타임 스텝의 은닉 states입니다.<br>
# states 매개변수는 하나 이상의 텐서를 담은 리스트입니다.
#
# 셀은 state_size와 output_size 속성을 가져야 합니다.<br>
# 간단한 RNN에서는 둘 다 모두 유닛 개수와 동일합니다.<br>
# 다음 코드는 SimpleRNNCell 처럼 작동하는 사용자 정의 메모리 셀을 구현합니다.<br>
# 각 타임 스텝마다 층 정규화를 적용한다는 점이 다릅니다.

# %%
from tensorflow.keras.layers import LayerNormalization

# %%
class LNSimpleRNNCell(keras.layers.Layer):
    def __init__(self, units, activation="tanh", **kwargs):
        super().__init__(**kwargs)
        self.state_size = units
        self.output_size = units
        self.simple_rnn_cell = keras.layers.SimpleRNNCell(units,
                                                          activation=None)
        self.layer_norm = LayerNormalization()
        self.activation = keras.activations.get(activation)
    def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
        if inputs is not None:
            batch_size = tf.shape(inputs)[0]
            dtype = inputs.dtype
        return [tf.zeros([batch_size, self.state_size], dtype=dtype)]
    def call(self, inputs, states):
        # 현재 입력과 이전 은닉 상태의 선형 조합 계산
        outputs, new_states = self.simple_rnn_cell(inputs, states)
        # 층 정규화와 활성화 함수를 차례대로 적용
        norm_outputs = self.activation(self.layer_norm(outputs))
        # 출력과 은닉 상태 반환
        return norm_outputs, [norm_outputs]

# %%
model = keras.models.Sequential([
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True,
                     input_shape=[None, 1]),
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 7s 26ms/step - loss: 0.1368 - last_time_step_mse: 0.1209 - val_loss: 0.0731 - val_last_time_step_mse: 0.0596
# Epoch 2/20
# 219/219 [==============================] - 5s 25ms/step - loss: 0.0626 - last_time_step_mse: 0.0512 - val_loss: 0.0572 - val_last_time_step_mse: 0.0444
# Epoch 3/20
# 219/219 [==============================] - 5s 25ms/step - loss: 0.0521 - last_time_step_mse: 0.0394 - val_loss: 0.0493 - val_last_time_step_mse: 0.0358
# Epoch 4/20
# 219/219 [==============================] - 5s 24ms/step - loss: 0.0469 - last_time_step_mse: 0.0340 - val_loss: 0.0449 - val_last_time_step_mse: 0.0314
# Epoch 5/20
# 219/219 [==============================] - 5s 24ms/step - loss: 0.0430 - last_time_step_mse: 0.0296 - val_loss: 0.0409 - val_last_time_step_mse: 0.0272
# Epoch 6/20
# 219/219 [==============================] - 5s 24ms/step - loss: 0.0389 - last_time_step_mse: 0.0249 - val_loss: 0.0378 - val_last_time_step_mse: 0.0226
# Epoch 7/20
# 219/219 [==============================] - 5s 24ms/step - loss: 0.0360 - last_time_step_mse: 0.0220 - val_loss: 0.0350 - val_last_time_step_mse: 0.0213
# Epoch 8/20
# 219/219 [==============================] - 5s 24ms/step - loss: 0.0340 - last_time_step_mse: 0.0203 - val_loss: 0.0330 - val_last_time_step_mse: 0.0190
# Epoch 9/20
# 219/219 [==============================] - 5s 25ms/step - loss: 0.0324 - last_time_step_mse: 0.0188 - val_loss: 0.0314 - val_last_time_step_mse: 0.0175
# Epoch 10/20
# 219/219 [==============================] - 5s 24ms/step - loss: 0.0313 - last_time_step_mse: 0.0176 - val_loss: 0.0307 - val_last_time_step_mse: 0.0172
# Epoch 11/20
# 219/219 [==============================] - 5s 24ms/step - loss: 0.0306 - last_time_step_mse: 0.0173 - val_loss: 0.0300 - val_last_time_step_mse: 0.0164- loss: 0.0306 - last_time_step_mse: 0.
# Epoch 12/20
# 219/219 [==============================] - 5s 25ms/step - loss: 0.0299 - last_time_step_mse: 0.0165 - val_loss: 0.0294 - val_last_time_step_mse: 0.0160
# Epoch 13/20
# 219/219 [==============================] - 5s 25ms/step - loss: 0.0292 - last_time_step_mse: 0.0158 - val_loss: 0.0292 - val_last_time_step_mse: 0.0159
# Epoch 14/20
# 219/219 [==============================] - 5s 24ms/step - loss: 0.0291 - last_time_step_mse: 0.0157 - val_loss: 0.0287 - val_last_time_step_mse: 0.0157
# Epoch 15/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0288 - last_time_step_mse: 0.0152 - val_loss: 0.0284 - val_last_time_step_mse: 0.0149
# Epoch 16/20
# 219/219 [==============================] - 6s 27ms/step - loss: 0.0281 - last_time_step_mse: 0.0149 - val_loss: 0.0280 - val_last_time_step_mse: 0.0148
# Epoch 17/20
# 219/219 [==============================] - 6s 27ms/step - loss: 0.0279 - last_time_step_mse: 0.0148 - val_loss: 0.0274 - val_last_time_step_mse: 0.0141
# Epoch 18/20
# 219/219 [==============================] - 6s 26ms/step - loss: 0.0275 - last_time_step_mse: 0.0144 - val_loss: 0.0272 - val_last_time_step_mse: 0.0141
# Epoch 19/20
# 219/219 [==============================] - 6s 26ms/step - loss: 0.0275 - last_time_step_mse: 0.0143 - val_loss: 0.0269 - val_last_time_step_mse: 0.0138
# Epoch 20/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0270 - last_time_step_mse: 0.0139 - val_loss: 0.0266 - val_last_time_step_mse: 0.0136

# %% [markdown]
# 비슷하게 타임 스텝 사이에 드롭아웃을 적용하는 사용자 정의 셀을 만들 수 있습니다.<br>
# 하지만 이는 그냥 keras.layers.RNN을 제외한 모든 순환 층과 케라스에서 제공하는 모든 셀은 dropout 매개변수(타임 스텝마다 입력에 적용하는 드롭아웃 비율)와 recurrent_dropout 매개변수(타임 스텝마다 은닉 상태에 대한 드롭아웃 비율)를 지원하므로 따로 사용자 정의 셀을 만들 필요는 없습니다.

# %% [markdown]
# ## LSTM 셀

# %%
model = keras.models.Sequential([
    keras.layers.LSTM(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.LSTM(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 8s 24ms/step - loss: 0.0774 - last_time_step_mse: 0.0638 - val_loss: 0.0543 - val_last_time_step_mse: 0.0342
# Epoch 2/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0473 - last_time_step_mse: 0.0259 - val_loss: 0.0418 - val_last_time_step_mse: 0.0220
# Epoch 3/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0387 - last_time_step_mse: 0.0173 - val_loss: 0.0363 - val_last_time_step_mse: 0.0160
# Epoch 4/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0349 - last_time_step_mse: 0.0149 - val_loss: 0.0335 - val_last_time_step_mse: 0.0143
# Epoch 5/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0327 - last_time_step_mse: 0.0139 - val_loss: 0.0315 - val_last_time_step_mse: 0.0133
# Epoch 6/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0311 - last_time_step_mse: 0.0131 - val_loss: 0.0306 - val_last_time_step_mse: 0.0134
# Epoch 7/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0299 - last_time_step_mse: 0.0125 - val_loss: 0.0292 - val_last_time_step_mse: 0.0123
# Epoch 8/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0288 - last_time_step_mse: 0.0117 - val_loss: 0.0281 - val_last_time_step_mse: 0.0112
# Epoch 9/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0279 - last_time_step_mse: 0.0111 - val_loss: 0.0274 - val_last_time_step_mse: 0.0109
# Epoch 10/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0273 - last_time_step_mse: 0.0106 - val_loss: 0.0271 - val_last_time_step_mse: 0.0103
# Epoch 11/20
# 219/219 [==============================] - 4s 21ms/step - loss: 0.0265 - last_time_step_mse: 0.0102 - val_loss: 0.0262 - val_last_time_step_mse: 0.0108
# Epoch 12/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0260 - last_time_step_mse: 0.0099 - val_loss: 0.0256 - val_last_time_step_mse: 0.0093
# Epoch 13/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0254 - last_time_step_mse: 0.0094 - val_loss: 0.0253 - val_last_time_step_mse: 0.0089
# Epoch 14/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0250 - last_time_step_mse: 0.0091 - val_loss: 0.0247 - val_last_time_step_mse: 0.0089
# Epoch 15/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0247 - last_time_step_mse: 0.0090 - val_loss: 0.0242 - val_last_time_step_mse: 0.0086
# Epoch 16/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0243 - last_time_step_mse: 0.0086 - val_loss: 0.0241 - val_last_time_step_mse: 0.0084
# Epoch 17/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.0241 - last_time_step_mse: 0.0084 - val_loss: 0.0238 - val_last_time_step_mse: 0.0089
# Epoch 18/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.0238 - last_time_step_mse: 0.0083 - val_loss: 0.0236 - val_last_time_step_mse: 0.0080
# Epoch 19/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.0236 - last_time_step_mse: 0.0081 - val_loss: 0.0236 - val_last_time_step_mse: 0.0081
# Epoch 20/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0235 - last_time_step_mse: 0.0084 - val_loss: 0.0231 - val_last_time_step_mse: 0.0083

# %%
model.evaluate(X_valid, Y_valid)
# Out:
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0231 - last_time_step_mse: 0.0083
# [0.02312830276787281, 0.00827905721962452]

# %% [markdown]
# ## 1D 합성곱 층을 사용해 시퀀스 처리하기
# 지금의 예는 앞의 모델과 같은데 스트라이드 2를 사용해 입력 시퀀스를 두 배로 다운샘플링하는 1D 합성곱 층으로 시작합니다. 커널 크기가 스트라이드보다 크므로 모든 입력을 사용해 이 층의 출력을 계산합니다. 따라서 모델이 중요하지 않은 세부 사항을 버리고 유용한 정보를 학습할 수 있습니다.

# %%
model = keras.models.Sequential([
    keras.layers.Conv1D(filters=20, kernel_size=4, strides=2, padding="valid",
                        input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train[:, 3::2], epochs=20,
                    validation_data=(X_valid, Y_valid[:, 3::2]))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 6s 15ms/step - loss: 0.0681 - last_time_step_mse: 0.0610 - val_loss: 0.0494 - val_last_time_step_mse: 0.0419
# Epoch 2/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0392 - last_time_step_mse: 0.0310 - val_loss: 0.0318 - val_last_time_step_mse: 0.0216
# Epoch 3/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0283 - last_time_step_mse: 0.0176 - val_loss: 0.0259 - val_last_time_step_mse: 0.0152
# Epoch 4/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0252 - last_time_step_mse: 0.0144 - val_loss: 0.0239 - val_last_time_step_mse: 0.0137
# Epoch 5/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0236 - last_time_step_mse: 0.0129 - val_loss: 0.0227 - val_last_time_step_mse: 0.0124
# Epoch 6/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0225 - last_time_step_mse: 0.0120 - val_loss: 0.0218 - val_last_time_step_mse: 0.0116
# Epoch 7/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0218 - last_time_step_mse: 0.0114 - val_loss: 0.0213 - val_last_time_step_mse: 0.0113
# Epoch 8/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0213 - last_time_step_mse: 0.0109 - val_loss: 0.0207 - val_last_time_step_mse: 0.0107
# Epoch 9/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0208 - last_time_step_mse: 0.0106 - val_loss: 0.0202 - val_last_time_step_mse: 0.0102
# Epoch 10/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0205 - last_time_step_mse: 0.0102 - val_loss: 0.0200 - val_last_time_step_mse: 0.0101
# Epoch 11/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0201 - last_time_step_mse: 0.0099 - val_loss: 0.0197 - val_last_time_step_mse: 0.0099
# Epoch 12/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0198 - last_time_step_mse: 0.0098 - val_loss: 0.0195 - val_last_time_step_mse: 0.0098
# Epoch 13/20
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0195 - last_time_step_mse: 0.0094 - val_loss: 0.0194 - val_last_time_step_mse: 0.0096
# Epoch 14/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0193 - last_time_step_mse: 0.0093 - val_loss: 0.0190 - val_last_time_step_mse: 0.0093
# Epoch 15/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0191 - last_time_step_mse: 0.0091 - val_loss: 0.0187 - val_last_time_step_mse: 0.0090
# Epoch 16/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0189 - last_time_step_mse: 0.0090 - val_loss: 0.0185 - val_last_time_step_mse: 0.0089
# Epoch 17/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0187 - last_time_step_mse: 0.0088 - val_loss: 0.0184 - val_last_time_step_mse: 0.0088
# Epoch 18/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0185 - last_time_step_mse: 0.0086 - val_loss: 0.0189 - val_last_time_step_mse: 0.0097
# Epoch 19/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0183 - last_time_step_mse: 0.0085 - val_loss: 0.0180 - val_last_time_step_mse: 0.0085
# Epoch 20/20
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0181 - last_time_step_mse: 0.0084 - val_loss: 0.0178 - val_last_time_step_mse: 0.0084

# %%
model.evaluate(X_valid, Y_valid[:, 3::2])
# Out:
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0178 - last_time_step_mse: 0.0084
# [0.0178215391933918, 0.008373051881790161]

# %% [markdown]
# 여태중에 가장 좋은 모델임을 알 수 있습니다.

# %% [markdown]
# ## WaveNet

# %%
model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for rate in (1, 2, 4, 8) * 2:
    model.add(keras.layers.Conv1D(filters=20, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate))
model.add(keras.layers.Conv1D(filters=10, kernel_size=1))
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 3s 8ms/step - loss: 0.0712 - last_time_step_mse: 0.0595 - val_loss: 0.0385 - val_last_time_step_mse: 0.0237
# Epoch 2/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0340 - last_time_step_mse: 0.0196 - val_loss: 0.0319 - val_last_time_step_mse: 0.0176
# Epoch 3/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0298 - last_time_step_mse: 0.0165 - val_loss: 0.0287 - val_last_time_step_mse: 0.0159
# Epoch 4/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0277 - last_time_step_mse: 0.0150 - val_loss: 0.0265 - val_last_time_step_mse: 0.0139
# Epoch 5/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0262 - last_time_step_mse: 0.0137 - val_loss: 0.0258 - val_last_time_step_mse: 0.0135
# Epoch 6/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0252 - last_time_step_mse: 0.0129 - val_loss: 0.0247 - val_last_time_step_mse: 0.0126
# Epoch 7/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0245 - last_time_step_mse: 0.0122 - val_loss: 0.0272 - val_last_time_step_mse: 0.0166
# Epoch 8/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0239 - last_time_step_mse: 0.0118 - val_loss: 0.0232 - val_last_time_step_mse: 0.0110
# Epoch 9/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0234 - last_time_step_mse: 0.0113 - val_loss: 0.0227 - val_last_time_step_mse: 0.0106
# Epoch 10/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0230 - last_time_step_mse: 0.0109 - val_loss: 0.0228 - val_last_time_step_mse: 0.0106
# Epoch 11/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0225 - last_time_step_mse: 0.0105 - val_loss: 0.0223 - val_last_time_step_mse: 0.0102
# Epoch 12/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0222 - last_time_step_mse: 0.0102 - val_loss: 0.0220 - val_last_time_step_mse: 0.0098
# Epoch 13/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0217 - last_time_step_mse: 0.0097 - val_loss: 0.0216 - val_last_time_step_mse: 0.0092
# Epoch 14/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0214 - last_time_step_mse: 0.0094 - val_loss: 0.0210 - val_last_time_step_mse: 0.0089
# Epoch 15/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0212 - last_time_step_mse: 0.0091 - val_loss: 0.0214 - val_last_time_step_mse: 0.0096
# Epoch 16/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0210 - last_time_step_mse: 0.0090 - val_loss: 0.0204 - val_last_time_step_mse: 0.0082
# Epoch 17/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0207 - last_time_step_mse: 0.0087 - val_loss: 0.0203 - val_last_time_step_mse: 0.0082
# Epoch 18/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0203 - last_time_step_mse: 0.0084 - val_loss: 0.0209 - val_last_time_step_mse: 0.0092
# Epoch 19/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0202 - last_time_step_mse: 0.0082 - val_loss: 0.0200 - val_last_time_step_mse: 0.0078
# Epoch 20/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0200 - last_time_step_mse: 0.0080 - val_loss: 0.0202 - val_last_time_step_mse: 0.0085

# %%
model.evaluate(X_valid, Y_valid)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0202 - last_time_step_mse: 0.0085
# [0.020175999030470848, 0.00847913883626461]

# %% [markdown]
# 마지막 두 모델이 이 시계열을 예측하는 데 가장 좋은 성능을 제공합니다.
